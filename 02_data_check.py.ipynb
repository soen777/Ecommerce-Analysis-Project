# %%
import pandas as pd
df = pd.read_csv("../data/cleaned_data.csv")

# %%
# 1. 看数据前5行
print(df.head())

# 2. 行为类型统计（点击/收藏/加购/支付）
print("\n用户行为分布：")
print(df['behavior'].value_counts())

# 3. 日期分布
print("\n日期分布：")
print(df['date'].value_counts().sort_index())
# Out:
#    user_id  item_id  category_id behavior   timestamp                 time  \
# 0        1  2576651       149192       pv  1511572885  2017-11-25 01:21:25
# 1        1  3830808      4181361       pv  1511593493  2017-11-25 07:04:53
# 2        1  4365585      2520377       pv  1511596146  2017-11-25 07:49:06
# 3        1  4606018      2735466       pv  1511616481  2017-11-25 13:28:01
# 4        1   230380       411153       pv  1511644942  2017-11-25 21:22:22
#
#          date  hour
# 0  2017-11-25     1
# 1  2017-11-25     7
# 2  2017-11-25     7
# 3  2017-11-25    13
# 4  2017-11-25    21
#
# 用户行为分布：
# behavior
# pv      15986274
# cart      989936
# fav       515706
# buy       362185
# Name: count, dtype: int64
#
# 日期分布：
# date
# 2017-11-25    1888940
# 2017-11-26    1899383
# 2017-11-27    1808681
# 2017-11-28    1784670
# 2017-11-29    1854895
# 2017-11-30    1897971
# 2017-12-01    2020251
# 2017-12-02    2533973
# 2017-12-03    2165337
# Name: count, dtype: int64
